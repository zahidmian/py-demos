# %%
import numpy as np
import pandas as pd
from numpy.random import randn

#stats
from scipy import stats

#plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([  6.,   8.,   6.,  12.,  16.,  22.,  11.,  11.,   6.,   2.]),
#  array([-2.05432185, -1.65235592, -1.25038998, -0.84842405, -0.44645812,
#         -0.04449218,  0.35747375,  0.75943968,  1.16140562,  1.56337155,
#          1.96533748]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)
plt.hist(dataset2, color='red')
# Out:
# (array([  3.,   4.,   5.,  14.,  10.,  18.,   6.,  12.,   5.,   3.]),
#  array([-2.31076116, -1.87094792, -1.43113469, -0.99132145, -0.55150821,
#         -0.11169498,  0.32811826,  0.76793149,  1.20774473,  1.64755797,
#          2.0873712 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, normed=True, color='red', alpha=0.5, bins=20)
plt.hist(dataset2, normed=True, alpha=0.5, bins=20)
# Out:
# (array([ 0.05684231,  0.11368462,  0.        ,  0.22736924,  0.17052693,
#          0.11368462,  0.34105386,  0.45473847,  0.28421155,  0.28421155,
#          0.45473847,  0.56842309,  0.22736924,  0.11368462,  0.34105386,
#          0.34105386,  0.17052693,  0.11368462,  0.11368462,  0.05684231]),
#  array([-2.31076116, -2.09085454, -1.87094792, -1.6510413 , -1.43113469,
#         -1.21122807, -0.99132145, -0.77141483, -0.55150821, -0.3316016 ,
#         -0.11169498,  0.10821164,  0.32811826,  0.54802488,  0.76793149,
#          0.98783811,  1.20774473,  1.42765135,  1.64755797,  1.86746458,
#          2.0873712 ]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)
sns.jointplot(data1, data2)

# %%
sns.jointplot(data1, data2, kind='hexplot')
